# %%
from matplotlib import pyplot as plt
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(
    channel='ibm_quantum_platform',
    instance='crn:v1:bluemix:public:quantum-computing:us-east:a/798c8822c77d46aa8bb82e6c957acc3b:8bcd1be8-39a6-4888-9339-02fa28e6699f::'
)
job = service.job('d48hdo210n3c73ecosd0')
job_result = job.result()

for idx, pub_result in enumerate(job_result):
    print(f"Expectation values for pub {idx}: {pub_result.data.evs}")

values = pub_result.data.evs

observables_labels = ["IZ", "IX", "ZI", "XI", "ZZ", "XX"]

# plotting graph
plt.plot(observables_labels, values, "-o")
plt.xlabel("Observables")
plt.ylabel("Values")
plt.show()
# Out:
# Expectation values for pub 0: [-0.00609484  0.02966156 -0.01695929  0.02150934  0.96554603  0.96343416]
